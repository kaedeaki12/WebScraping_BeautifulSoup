# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/Wikipedia:Fundraising_statistics"
tables = pd.read_html(url)

# %%
type(tables)
# Out:
# list

# %%
len(tables)
# Out:
# 1

# %%
tables[0].head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570

# %%
fundraising = tables[0]

# %%
type(fundraising)
# Out:
# pandas.core.frame.DataFrame

# %%
fundraising.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# dtype: object

# %%
fundraising['Rev'] = fundraising['Revenue'].str[2:]

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#            Rev
# 0  154,686,521
# 1  162,886,686
# 2  129,234,327
# 3  120,067,266
# 4  104,505,783

# %%
fundraising['Rev'] = fundraising['Rev'].str.replace(',','')

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          Rev
# 0  154686521
# 1  162886686
# 2  129234327
# 3  120067266
# 4  104505783

# %%
fundraising.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# Rev             object
# dtype: object

# %%
fundraising['Rev'] = pd.to_numeric(fundraising['Rev'])

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          Rev
# 0  154686521
# 1  162886686
# 2  129234327
# 3  120067266
# 4  104505783

# %%
fundraising.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# Rev              int64
# dtype: object

# %%
fundraising['Exp'] = fundraising['Expenses'].str[2:]

fundraising['Exp'] = fundraising['Exp'].str.replace(',','')

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          Rev        Exp
# 0  154686521  145970915
# 1  162886686  111839819
# 2  129234327  112489397
# 3  120067266   91414010
# 4  104505783   81442265

# %%
fundraising.loc[0, 'Exp'] = 'spam'

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          Rev        Exp
# 0  154686521       spam
# 1  162886686  111839819
# 2  129234327  112489397
# 3  120067266   91414010
# 4  104505783   81442265

# %%
fundraising['Exp'] = pd.to_numeric(fundraising['Exp'], errors = 'coerce')

# %%
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          Rev          Exp
# 0  154686521          NaN
# 1  162886686  111839819.0
# 2  129234327  112489397.0
# 3  120067266   91414010.0
# 4  104505783   81442265.0

# %%
fundraising.dtypes
# Out:
# Year             object
# Source           object
# Revenue          object
# Expenses         object
# Asset rise       object
# Total assets     object
# Rev               int64
# Exp             float64
# dtype: object

# %%
fundraising['Revenue'] = fundraising['Revenue'].str[2:]
fundraising['Expenses'] = fundraising['Expenses'].str[2:]
fundraising['Asset rise'] = fundraising['Asset rise'].str[2:]
fundraising['Total assets'] = fundraising['Total assets'].str[2:]

# %%
fundraising['Revenue'] = fundraising['Revenue'].str.replace(',','')
fundraising['Expenses'] = fundraising['Expenses'].str.replace(',','')
fundraising['Asset rise'] = fundraising['Asset rise'].str.replace(',','')
fundraising['Total assets'] = fundraising['Total assets'].str.replace(',','')

# %%
fundraising['Revenue'] = pd.to_numeric(fundraising['Revenue'], errors = 'coerce')
fundraising['Expenses'] = pd.to_numeric(fundraising['Expenses'], errors = 'coerce')
fundraising['Asset rise'] = pd.to_numeric(fundraising['Asset rise'], errors = 'coerce')
fundraising['Total assets'] = pd.to_numeric(fundraising['Total assets'], errors = 'coerce')

# %%
fundraising.dtypes
# Out:
# Year             object
# Source           object
# Revenue           int64
# Expenses          int64
# Asset rise        int64
# Total assets      int64
# Rev               int64
# Exp             float64
# dtype: object

# %%
fundraising.head()
# Out:
#       Year Source    Revenue  Expenses  Asset rise  Total assets        Rev  \
# 0  2021/22    PDF  154686521   5970915     8173996     239351532  154686521
# 1  2020/21    PDF  162886686   1839819    50861811     231177536  162886686
# 2  2019/20    PDF  129234327   2489397    14674300     180315725  129234327
# 3  2018/19    PDF  120067266    414010    30691855     165641425  120067266
# 4  2017/18    PDF  104505783    442265    21619373     134949570  104505783
#
#            Exp
# 0          NaN
# 1  111839819.0
# 2  112489397.0
# 3   91414010.0
# 4   81442265.0

# %%
fundraising.to_csv("table.csv")
